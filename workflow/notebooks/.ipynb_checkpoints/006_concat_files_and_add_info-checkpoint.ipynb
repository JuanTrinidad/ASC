# %%
import pandas as pd

# %% [markdown]
# ## funtion for pipe

# %%
def get_only_uniprot_accession(df, colname):
    
    colname_out = colname + '_uniprot_accession'
    
    df[colname_out] = df[colname].str.split('-', expand=True)[1]
    
    return df


def calc_coverage(df, which_one ,start, end, lenght):
    
    col_name = 'COV_' + which_one
    
    df[col_name] = (df.loc[: , end] - df.loc[: , start]) / df.loc[: , lenght]
    
    df[col_name] = df[col_name].round(2)
    
    return df

# %% [markdown]
# ## concatenating all tsv data frames

# %%
list_of_df = []
for file in snakemake.input:
    
    df = pd.read_csv(file, sep='\t', names=['query','target','alnlen','fident', 'evalue', 'qstart','qend', 'qlen','tstart','tend','tlen','aligmentinfo'])
    
    #info from file name
    info = file.split('_')[-4:-1]
    df['proteome'] = info[0]
    df['spp'] = info[-1]
    
    #appending_list
    list_of_df.append(df)
    #print(file)

# %%
df = pd.concat(list_of_df)

# %%
df = (df
 .pipe(get_only_uniprot_accession, 'query')
 .pipe(get_only_uniprot_accession, 'target')
 .pipe(calc_coverage, 'query', 'qstart', 'qend','qlen')
 .pipe(calc_coverage, 'target', 'tstart', 'tend','tlen'))

# %%
df
# Out:
#                                                   query  \
# 0                             AF-A4HVJ7-F1-model_v4.pdb
# 1                             AF-A4HVJ7-F1-model_v4.pdb
# 2     AF-wheelerlab_Tb927.7.1570_1_1399_1-F1-model_v...
# 3                         AF-A0A1X0NNE1-F1-model_v4.pdb
# 4                         AF-A0A1X0NNE1-F1-model_v4.pdb
# ...                                                 ...
# 2062                          AF-Q4D887-F1-model_v4.pdb
# 2063                          AF-Q4D887-F1-model_v4.pdb
# 2064                      AF-A0A088RUA8-F1-model_v4.pdb
# 2065                          AF-A4I013-F1-model_v4.pdb
# 2066                          AF-A4I013-F1-model_v4.pdb
#
#                             target  alnlen  fident        evalue  qstart  \
# 0     AF-X8FIQ5-F1-model_v4.pdb.gz      50   0.114  2.134000e-03     705
# 1     AF-X8FIQ5-F1-model_v4.cif.gz      50   0.114  2.134000e-03     705
# 2     AF-X8FDP3-F1-model_v4.cif.gz      32   0.109  7.084000e-01    1286
# 3     AF-X8FH37-F1-model_v4.pdb.gz     148   0.154  1.288000e-05     201
# 4     AF-X8FH37-F1-model_v4.cif.gz     148   0.154  1.288000e-05     201
# ...                            ...     ...     ...           ...     ...
# 2062  AF-Q32FH6-F1-model_v4.pdb.gz     777   0.278  7.295000e-23       4
# 2063  AF-Q32FH6-F1-model_v4.cif.gz     777   0.278  7.295000e-23       4
# 2064  AF-Q32AC7-F1-model_v4.cif.gz      49   0.181  5.182000e-02     106
# 2065  AF-Q32CN1-F1-model_v4.pdb.gz    3038   0.351  2.469000e-78       6
# 2066  AF-Q32CN1-F1-model_v4.cif.gz    3038   0.351  2.469000e-78       6
#
#       qend  qlen  tstart  tend  tlen  \
# 0      946   956       0   201   326
# 1      946   956       0   201   326
# 2     1350  1399      10    76   104
# 3      369   370       0   142   152
# 4      369   370       0   142   152
# ...    ...   ...     ...   ...   ...
# 2062   293   295       4   282   286
# 2063   293   295       4   282   286
# 2064   236   494       1   123   154
# 2065   957   962       3   873   876
# 2066   957   962       3   873   876
#
#                                            aligmentinfo     proteome    spp  \
# 0     11M1D16M9D47M2I7M27I23M5I4M6D5M6I4M7I8M4I1M2I3...  UP000020681  MYCUL
# 1     11M1D16M9D47M2I7M27I23M5I4M6D5M6I4M7I8M4I1M2I3...  UP000020681  MYCUL
# 2                                 8M1D13M6I16M3D5M4D17M  UP000020681  MYCUL
# 3                    16M13D20M1I13M3D7M15I15M29I47M3D6M  UP000020681  MYCUL
# 4                    16M13D20M1I13M3D7M15I15M29I47M3D6M  UP000020681  MYCUL
# ...                                                 ...          ...    ...
# 2062     10M1D23M2I28M2D30M6I6M1D11M1I64M4I5M1I19M1I79M  UP000002716  SHIDS
# 2063     10M1D23M2I28M2D30M6I6M1D11M1I64M4I5M1I19M1I79M  UP000002716  SHIDS
# 2064                         14M1D32M2I17M4I43M1I8M2I8M  UP000002716  SHIDS
# 2065  55M5I60M2D17M8I6M2D15M7D23M4D7M2I73M8I4M3I46M1...  UP000002716  SHIDS
# 2066  55M5I60M2D17M8I6M2D15M7D23M4D7M2I73M8I4M3I46M1...  UP000002716  SHIDS
#
#                query_uniprot_accession target_uniprot_accession  COV_query  \
# 0                               A4HVJ7                   X8FIQ5       0.25
# 1                               A4HVJ7                   X8FIQ5       0.25
# 2     wheelerlab_Tb927.7.1570_1_1399_1                   X8FDP3       0.05
# 3                           A0A1X0NNE1                   X8FH37       0.45
# 4                           A0A1X0NNE1                   X8FH37       0.45
# ...                                ...                      ...        ...
# 2062                            Q4D887                   Q32FH6       0.98
# 2063                            Q4D887                   Q32FH6       0.98
# 2064                        A0A088RUA8                   Q32AC7       0.26
# 2065                            A4I013                   Q32CN1       0.99
# 2066                            A4I013                   Q32CN1       0.99
#
#       COV_target
# 0           0.62
# 1           0.62
# 2           0.63
# 3           0.93
# 4           0.93
# ...          ...
# 2062        0.97
# 2063        0.97
# 2064        0.79
# 2065        0.99
# 2066        0.99
#
# [8120 rows x 18 columns]

# %%
df.to_csv(snakemake.output[0], sep='\t')
