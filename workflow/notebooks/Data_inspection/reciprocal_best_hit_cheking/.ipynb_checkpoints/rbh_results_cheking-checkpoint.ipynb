# %%
import pandas as pd
import glob

# %% [markdown]
# ## funtion for pipe

# %%
def get_only_uniprot_accession(df, colname):
    
    colname_out = colname + '_uniprot_accession'
    
    df[colname_out] = df[colname].str.split('-', expand=True)[1]
    
    return df


def calc_coverage(df, which_one ,start, end, lenght):
    
    col_name = 'COV_' + which_one
    
    df[col_name] = (df.loc[: , end] - df.loc[: , start]) / df.loc[: , lenght]
    
    return df

# %%
(df.loc[: , 'qend'] - df.loc[: , 'qstart']) /
# Out:
# 0       905
# 1       905
# 2       140
# 3       435
# 4       435
#        ...
# 1902    328
# 1903    328
# 1904    111
# 1905    111
# 1906    108
# Length: 226912, dtype: int64

# %% [markdown]
# ## concatenating all tsv data frames

# %%
list_of_df = []
for file in glob.glob('../../../report_files/reciprocal_best_hit_TSV/*.tsv'):
    
    df = pd.read_csv(file, sep='\t', names=['query','target','alnlen','fident', 'evalue', 'qstart','qend', 'qlen','tstart','tend','tlen'])
    
    #info from file name
    info = file.split('_')[-4:-1]
    df['proteome'] = info[0]
    df['spp'] = info[-1]
    
    #appending_list
    list_of_df.append(df)
    #print(file)

# %%
df = pd.concat(list_of_df)

# %%
df.columns
# Out:
# Index(['query', 'target', 'alnlen', 'fident', 'evalue', 'qstart', 'qend',
#        'qlen', 'tstart', 'tend', 'tlen', 'proteome', 'spp'],
#       dtype='object')

# %% [markdown]
# ## df inspection and cheking
# * some target are duplicated because they have a .pdb and .cif file. -> remove .cif if there is allready a .pdb

# %%
df.sort_values('query')
# Out:
#                               query                            target  alnlen  \
# 2398  AF-A0A061IRH8-F1-model_v4.pdb  AF-A0A0G2JWU6-F1-model_v4.cif.gz      35
# 2397  AF-A0A061IRH8-F1-model_v4.pdb  AF-A0A0G2JWU6-F1-model_v4.pdb.gz      35
# 2331  AF-A0A061IRH9-F1-model_v4.pdb  AF-A0A0D2GWR0-F1-model_v4.cif.gz      29
# 1002  AF-A0A061IRH9-F1-model_v4.pdb      AF-Q54ZR5-F1-model_v4.cif.gz      39
# 2330  AF-A0A061IRH9-F1-model_v4.pdb  AF-A0A0D2GWR0-F1-model_v4.pdb.gz      29
# ...                             ...                               ...     ...
# 6475      AF-V5DU47-F1-model_v4.pdb  AF-A0A0P0WEN5-F1-model_v4.cif.gz      37
# 8840      AF-V5DU65-F1-model_v4.pdb      AF-Q4E613-F1-model_v4.pdb.gz     555
# 8841      AF-V5DU65-F1-model_v4.pdb      AF-Q4E613-F1-model_v4.cif.gz     555
# 5909      AF-V5DUQ7-F1-model_v4.pdb      AF-Q38DG5-F1-model_v4.pdb.gz    1368
# 5908      AF-V5DUQ7-F1-model_v4.pdb      AF-Q38DG5-F1-model_v4.cif.gz    1368
#
#       fident        evalue  qstart  qend  qlen  tstart  tend  tlen  \
# 2398   0.142  1.256000e+00       0    69    71       0    69    72
# 2397   0.142  1.256000e+00       0    69    71       0    69    72
# 2331   0.141  3.252000e-01       0    84    87       1    77    82
# 1002   0.153  2.806000e+00      47    85    87       1    39    43
# 2330   0.141  3.252000e-01       0    84    87       1    77    82
# ...      ...           ...     ...   ...   ...     ...   ...   ...
# 6475   0.215  5.901000e-01       9    94    95       0    87    88
# 8840   0.927  7.722000e-25       0   179   180       0   179   180
# 8841   0.927  7.722000e-25       0   179   180       0   179   180
# 5909   0.469  8.490000e-43       0   376   377     956  1344  1345
# 5908   0.469  8.490000e-43       0   376   377     956  1344  1345
#
#          proteome     spp
# 2398  UP000002494     RAT
# 2397  UP000002494     RAT
# 2331  UP000053029  9EURO2
# 1002  UP000002195   DICDI
# 2330  UP000053029  9EURO2
# ...           ...     ...
# 6475  UP000059680   ORYSJ
# 8840  UP000002296   TRYCC
# 8841  UP000002296   TRYCC
# 5909  UP000008524   TRYB2
# 5908  UP000008524   TRYB2
#
# [226912 rows x 13 columns]

# %%
df = (df
 .pipe(get_only_uniprot_accession, 'query')
 .pipe(get_only_uniprot_accession, 'target')
 .pipe(calc_coverage, 'query', 'qstart', 'qend','qlen'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 'qstart')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df = (df
#       2  .pipe(get_only_uniprot_accession, 'query')
#       3  .pipe(get_only_uniprot_accession, 'target')
#       4  .pipe(calc_coverage, 'query', 'qstart', 'qend','qlen'))
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5839, in NDFrame.pipe(self, func, *args, **kwargs)
#    5781 @final
#    5782 @doc(klass=_shared_doc_kwargs["klass"])
#    5783 def pipe(
#    (...)
#    5787     **kwargs,
#    5788 ) -> T:
#    5789     r"""
#    5790     Apply chainable functions that expect Series or DataFrames.
#    5791
#    (...)
#    5837     ...  )  # doctest: +SKIP
#    5838     """
# -> 5839     return com.pipe(self, func, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/common.py:513, in pipe(obj, func, *args, **kwargs)
#     511     return func(*args, **kwargs)
#     512 else:
# --> 513     return func(obj, *args, **kwargs)
#
# Cell In[54], line 14, in calc_coverage(df, which_one, start, end, lenght)
#      10 def calc_coverage(df, which_one ,start, end, lenght):
#      12     col_name = 'COV_' + which_one
# ---> 14     df[col_name] = (df.loc[: , end] - df [: , start]) / df[: , lenght]
#      16     return df
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key, method, tolerance)
#    3804         raise KeyError(key) from err
#    3805     except TypeError:
#    3806         # If we have a listlike key, _check_indexing_error will raise
#    3807         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808         #  the TypeError.
# -> 3809         self._check_indexing_error(key)
#    3810         raise
#    3812 # GH#42269
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:5925, in Index._check_indexing_error(self, key)
#    5921 def _check_indexing_error(self, key):
#    5922     if not is_scalar(key):
#    5923         # if key is not a scalar, directly raise an error (the code below
#    5924         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 'qstart')

# %%
df = df.drop_duplicates(['query_uniprot_accession', 'target_uniprot_accession'])

# %%
df
# Out:
#                               query                            target  alnlen  \
# 0     AF-A0A0S4JJ38-F1-model_v4.pdb  AF-A0A1D8PSB1-F1-model_v4.pdb.gz    1116
# 2     AF-A0A0S4KNY4-F1-model_v4.pdb  AF-A0A1D8PGQ1-F1-model_v4.pdb.gz      33
# 3     AF-A0A2V2V713-F1-model_v4.pdb      AF-P83783-F1-model_v4.cif.gz    2847
# 5     AF-A0A1X0NGE0-F1-model_v4.pdb  AF-A0A1D8PTT8-F1-model_v4.cif.gz      21
# 6     AF-A0A7G2CN12-F1-model_v4.pdb      AF-Q59ZG8-F1-model_v4.cif.gz      58
# ...                             ...                               ...     ...
# 1898      AF-Q581T7-F1-model_v4.pdb  AF-A0A132P9F6-F1-model_v4.pdb.gz     300
# 1900  AF-A0A0S4IQH1-F1-model_v4.pdb  AF-A0A132Z9A3-F1-model_v4.pdb.gz     348
# 1902      AF-G0TTI1-F1-model_v4.pdb  AF-A0A132Z0H4-F1-model_v4.pdb.gz    1299
# 1904      AF-Q4D6W7-F1-model_v4.pdb      AF-D8V1H1-F1-model_v4.pdb.gz     432
# 1906      AF-Q4D0C8-F1-model_v4.pdb      AF-E3USP1-F1-model_v4.pdb.gz      56
#
#       fident        evalue  qstart  qend  qlen  tstart  tend  tlen  \
# 0      0.151  6.654000e-41      46   951   959       1   813   816
# 2      0.127  8.504000e-02     329   469   646       0   135   163
# 3      0.676  3.458000e-69       1   436   437       6   449   450
# 5      0.128  4.756000e-01       0   100   123       0    86    87
# 6      0.200  3.094000e-01     730   842   891      18   124   125
# ...      ...           ...     ...   ...   ...     ...   ...   ...
# 1898   0.213  6.694000e-09       7   177   205       1   152   158
# 1900   0.153  1.009000e-13      35   369   370      42   313   315
# 1902   0.372  1.338000e-39       3   331   333       0   323   327
# 1904   0.283  1.873000e-11     125   236   278       2   114   115
# 1906   0.100  2.057000e-01      36   144   158       0    93   100
#
#          proteome    spp query_uniprot_accession target_uniprot_accession
# 0     UP000000559  CANAL              A0A0S4JJ38               A0A1D8PSB1
# 2     UP000000559  CANAL              A0A0S4KNY4               A0A1D8PGQ1
# 3     UP000000559  CANAL              A0A2V2V713                   P83783
# 5     UP000000559  CANAL              A0A1X0NGE0               A0A1D8PTT8
# 6     UP000000559  CANAL              A0A7G2CN12                   Q59ZG8
# ...           ...    ...                     ...                      ...
# 1898  UP000325664  ENTFC                  Q581T7               A0A132P9F6
# 1900  UP000325664  ENTFC              A0A0S4IQH1               A0A132Z9A3
# 1902  UP000325664  ENTFC                  G0TTI1               A0A132Z0H4
# 1904  UP000325664  ENTFC                  Q4D6W7                   D8V1H1
# 1906  UP000325664  ENTFC                  Q4D0C8                   E3USP1
#
# [138904 rows x 15 columns]

# %%
df[df.query_uniprot_accession == 'A0A7G2CN12']
# Out:
#                               query                            target  alnlen  \
# 6     AF-A0A7G2CN12-F1-model_v4.pdb      AF-Q59ZG8-F1-model_v4.cif.gz      58
# 644   AF-A0A7G2CN12-F1-model_v4.pdb  AF-A0A3P7E385-F1-model_v4.cif.gz     187
# 902   AF-A0A7G2CN12-F1-model_v4.pdb      AF-P45508-F1-model_v4.cif.gz     100
# 2496  AF-A0A7G2CN12-F1-model_v4.pdb  AF-A0A044RWX4-F1-model_v4.cif.gz      63
