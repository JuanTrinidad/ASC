# %%
import pandas as pd
import glob
import seaborn as sns

# %% [markdown]
# ## funtion for pipe

# %%
def get_only_uniprot_accession(df, colname):
    
    colname_out = colname + '_uniprot_accession'
    
    df[colname_out] = df[colname].str.split('-', expand=True)[1]
    
    return df


def calc_coverage(df, which_one ,start, end, lenght):
    
    col_name = 'COV_' + which_one
    
    df[col_name] = (df.loc[: , end] - df.loc[: , start]) / df.loc[: , lenght]
    
    df[col_name] = df[col_name].round(2)
    
    return df

# %% [markdown]
# ## concatenating all tsv data frames

# %%
list_of_df = []
for file in glob.glob('../../../../results/reciprocal_best_hit_TSV/*.tsv'):
    
    df = pd.read_csv(file, sep='\t', names=['query','target','alnlen','fident', 'evalue', 'qstart','qend', 'qlen','tstart','tend','tlen','aligmentinfo'])
    
    #info from file name
    info = file.split('_')[-4:-1]
    df['proteome'] = info[0]
    df['spp'] = info[-1]
    
    #appending_list
    list_of_df.append(df)
    #print(file)

# %%
df = pd.concat(list_of_df)

# %%
len(list_of_df)
# Out:
# 48

# %% [markdown]
# ## saco de los subject los kinetoplastidos

# %%
df = df.loc[~df['spp'].isin(['TRYCC','TRYB2','LEIIN']),:]

# %%
df.spp.unique()
# Out:
# array(['CANAL', '9EURO2', 'DROME', 'STAA8', 'ARATH', 'PARBA', 'MOUSE',
#        'RAT', 'YEAST', 'SOYBN', 'ORYSJ', 'HUMAN', 'SPOS1', '9EURO1',
#        'CAEEL', 'WUCBA', 'SCHMA', 'ECOLI', 'MYCUL', 'HELPY', 'DANRE',
#        'CAMJE', 'SHIDS', 'NEIG1', 'HAEIN', 'MAIZE', 'DICDI', 'PSEAE',
#        '9NOCA1', 'METJA', 'SALTY', 'TRITR', 'ONCVO', 'STRR6', 'PLAF7',
#        'SCHPO', 'BRUMA', 'AJECG', '9PEZI1', 'STRER', 'MYCLE', 'MYCTU',
#        'KLEPH', 'DRAME', 'ENTFC'], dtype=object)

# %% [markdown]
# ## df inspection and cheking
# * some target are duplicated because they have a .pdb and .cif file. -> remove .cif if there is allready a .pdb #rbh return both so is not a problem for the analysis.
# * some ortho groups from single members have the same structure assigned by tritrypDB. So we will find them duplicated.

# %%
df = (df
 .pipe(get_only_uniprot_accession, 'query')
 .pipe(get_only_uniprot_accession, 'target')
 .pipe(calc_coverage, 'query', 'qstart', 'qend','qlen')
 .pipe(calc_coverage, 'target', 'tstart', 'tend','tlen'))

print(df.shape)

df = df.drop_duplicates(['query_uniprot_accession', 'target_uniprot_accession'])

print(df.shape)
# Out:
# (188309, 18)
# (118739, 18)

# %%
#dataframe with GO annotation informattion
df_gene_information = pd.read_csv('../../../tmp/GenesByOrthologPattern_Summary.txt',
                                  sep='\t',
                                  low_memory=False)

ortho_g_count = df_gene_information.groupby('Ortholog Group').size().to_frame()
ortho_g_count = ortho_g_count[ortho_g_count[0] > 10]

# %% [markdown]
# ## Amount of cluster with rbh result

# %%
df_ogup = pd.read_csv('../../../report/ortholog_groups_x_sequence_clustering_x_UNIPROT.tsv', sep='\t')

# %%
df_ogup = df_ogup[~df_ogup.uniprot.isna()]

# %%
print('Total amount of cluster to annotate:')
print(df_ogup.Ortholog_Group.nunique())
# Out:
# Total amount of cluster to annotate:
# 30915

# %%
#merging df 
df_merged = df_ogup.merge(df, left_on='uniprot', right_on='query_uniprot_accession', how='right')

# %%
print('Total amount of cluster with hit in rbh approach:')
print(df_merged.Ortholog_Group.nunique())
# Out:
# Total amount of cluster with hit in rbh approach:
# 20796

# %%
data = df_merged.groupby('Ortholog_Group')['spp'].count().to_frame()
data.columns = ['spp_count']
#data = data[data >= 10]
#data = data[data <= 10]

print(len(data.index))

sns.displot(data=data)
sns.displot(data=data,kind='ecdf')
# Out:
# 20796

# %%
## adding count info 

df_merged = df_merged.merge(data, left_on='Ortholog_Group', right_index=True  ,how='left')

# %% [markdown]
# # Plotting some usefull info

# %%
sns.scatterplot(data = df_merged, #.sample(frac=.1), 
                x='pLDDT_mean', 
                y='fident', 
                #marker ='.',
               alpha=0.1)
# Out:
# <Axes: xlabel='pLDDT_mean', ylabel='fident'>

# %%
sns.scatterplot(data = df_merged.drop_duplicates(subset=['Ortholog_Group']), #.sample(frac=.1), 
                x='pLDDT_mean', 
                y='spp_count', 
                #marker ='.',
               alpha=0.2)
# Out:
# <Axes: xlabel='pLDDT_mean', ylabel='spp_count'>

# %%
df_merged[
    (df_merged['COV_query'] > .7) &
    (df_merged['COV_target'] > .7) &
    (df_merged['evalue'] < 1e-3)].sort_values('evalue').Ortholog_Group.nunique()
# Out:
# 8956

# %%
df_merged.sort_values('COV_target')
# Out:
#        Ortholog_Group           Gene ID     uniprot  pLDDT_mean  \
# 92909      OG6_156870        BSAL_20685  A0A0S4JD12        70.0
# 13020      OG6_102883   ADEAN_000358100  A0A7G2C8E0        95.0
# 86818      OG6_460183        BSAL_89600  A0A0S4KNL2        48.0
# 17178   OG6r16_198594  TcIL3000_0_56110      F9WCQ0        36.0
# 67304      OG6_456551        BSAL_35555  A0A0S4JP90        45.0
# ...               ...               ...         ...         ...
# 102308  OG6r16_105267    TM35_000074040  A0A1X0P3I7        60.0
# 43260      OG6_103995   TcCLB.508899.30      Q4DMP9        77.0
# 114574     OG6_101904   TEOVI_000269600  A0A1G4IFL4        89.0
# 81856      OG6_102018  TcCLB.510187.160      Q4E4D5        85.0
# 36399      OG6_478589   LpyrH10_21_0480  A0A0M9FU57        74.0
#
#                                 query                            target  \
# 92909   AF-A0A0S4JD12-F1-model_v4.pdb  AF-A0A044VBR3-F1-model_v4.pdb.gz
# 13020   AF-A0A7G2C8E0-F1-model_v4.pdb      AF-F4JP86-F1-model_v4.pdb.gz
# 86818   AF-A0A0S4KNL2-F1-model_v4.pdb      AF-K0EN14-F1-model_v4.pdb.gz
# 17178       AF-F9WCQ0-F1-model_v4.pdb      AF-C1GQN0-F1-model_v4.pdb.gz
# 67304   AF-A0A0S4JP90-F1-model_v4.pdb      AF-E7F6C7-F1-model_v4.pdb.gz
# ...                               ...                               ...
# 102308  AF-A0A1X0P3I7-F1-model_v4.pdb  AF-A0A5S6P6X7-F1-model_v4.cif.gz
# 43260       AF-Q4DMP9-F1-model_v4.pdb      AF-Q05048-F1-model_v4.pdb.gz
# 114574  AF-A0A1G4IFL4-F1-model_v4.pdb  AF-A0A0H3GGQ9-F1-model_v4.pdb.gz
# 81856       AF-Q4E4D5-F1-model_v4.pdb      AF-Q54HP3-F1-model_v4.pdb.gz
# 36399   AF-A0A0M9FU57-F1-model_v4.pdb      AF-Q10NJ2-F1-model_v4.pdb.gz
#
#         alnlen  fident        evalue  qstart  ...  tend  tlen  \
# 92909       28   0.121  4.559000e+00       0  ...  1110  1140
# 13020      444   0.448  2.332000e-12       1  ...  1827  1828
# 86818      127   0.220  1.172000e-03     144  ...   788   840
# 17178       36   0.139  5.017000e-02       2  ...  1737  2014
# 67304       29   0.159  8.448000e-01      23  ...  1354  1364
# ...        ...     ...           ...     ...  ...   ...   ...
# 102308      98   0.137  3.590000e-06      28  ...   389   390
# 43260     1103   0.218  1.702000e-35      39  ...   430   431
# 114574     536   0.235  9.422000e-19       0  ...   222   223
# 81856     2331   0.656  1.910000e-63       0  ...   369   370
# 36399       53   0.149  5.275000e-03       0  ...   443   445
#
#                                              aligmentinfo     proteome  \
# 92909                                                 41M  UP000024404
# 13020                                            33M1I82M  UP000006548
# 86818                                            19M1I30M  UP000006304
# 17178         17M4I27M3I8M1I3M3D7M2D17M6D4M8I3M2D17M2I17M  UP000002059
# 67304                              8M1D20M3D14M2I31M1D14M  UP000000437
# ...                                                   ...          ...
# 102308  39M2D29M5D10M5D23M1D14M5D3M3D21M1I8M3I25M1I32M...  UP000006672
# 43260   5M4D31M3D3M5I21M2I14M5I3M1D18M1I32M4I8M15I16M3...  UP000005640
# 114574  7M11I16M39I4M10I66M7I43M2I3M21I6M4I11M1I13M1I2...  UP000007841
# 81856                                     47M1D147M2D173M  UP000002195
# 36399   7M2D39M18D27M2D11M1D14M1D10M6D42M2I76M8D55M2D3...  UP000059680
#
#            spp query_uniprot_accession target_uniprot_accession COV_query  \
# 92909    ONCVO              A0A0S4JD12               A0A044VBR3      0.67
# 13020    ARATH              A0A7G2C8E0                   F4JP86      0.98
# 86818   9NOCA1              A0A0S4KNL2                   K0EN14      0.18
# 17178    PARBA                  F9WCQ0                   C1GQN0      0.84
# 67304    DANRE              A0A0S4JP90                   E7F6C7      0.79
# ...        ...                     ...                      ...       ...
# 102308   BRUMA              A0A1X0P3I7               A0A5S6P6X7      0.73
# 43260    HUMAN                  Q4DMP9                   Q05048      0.92
# 114574   KLEPH              A0A1G4IFL4               A0A0H3GGQ9      1.00
# 81856    DICDI                  Q4E4D5                   Q54HP3      0.99
# 36399    ORYSJ              A0A0M9FU57                   Q10NJ2      0.97
#
#        COV_target spp_count
# 92909        0.04         2
# 13020        0.06         5
# 86818        0.06         4
# 17178        0.07        14
# 67304        0.07         4
# ...           ...       ...
# 102308       1.00         8
# 43260        1.00        19
# 114574       1.00        14
# 81856        1.00        28
# 36399        1.00         1
#
# [120428 rows x 23 columns]

# %%
df_merged[(df_merged['pLDDT_mean'] < 60 ) & (df_merged['Gene ID'].str.contains('Tb'))] #[df_merged['Ortholog_Group'] == 'OG6r16_102156'].sort_values('fident')
# Out:
#        Ortholog_Group          Gene ID uniprot  pLDDT_mean  \
# 341     OG6r16_510959    Tbg972.3.1640  C9ZK61        56.0
# 457     OG6r16_147933  Tbg972.11.17140  D0AA93        40.0
# 745        OG6_106744     Tb927.7.5380  Q582F3        53.0
# 784        OG6_223517   Tb927.10.14270  Q388H5        54.0
# 1261       OG6_389361     Tb927.7.7160  Q57XT6        54.0
# ...               ...              ...     ...         ...
# 119813     OG6_389273   Tb927.11.14060  Q382D1        55.0
# 119870     OG6_389703      Tb927.7.750  Q57VS1        55.0
# 120018  OG6r16_147945    Tbg972.9.9110  C9ZZI6        32.0
# 120036     OG6_389077   Tb927.11.13160  Q382M0        34.0
# 120405     OG6_389272    Tb927.10.5730  Q38B31        45.0
#
#                             query                            target  alnlen  \
# 341     AF-C9ZK61-F1-model_v4.pdb      AF-Q5ADW0-F1-model_v4.cif.gz      52
# 457     AF-D0AA93-F1-model_v4.pdb      AF-Q5A512-F1-model_v4.pdb.gz      31
# 745     AF-Q582F3-F1-model_v4.pdb  AF-A0A1D8PQM1-F1-model_v4.pdb.gz     317
# 784     AF-Q388H5-F1-model_v4.pdb      AF-Q5A7R0-F1-model_v4.pdb.gz     284
# 1261    AF-Q57XT6-F1-model_v4.pdb      AF-Q5APU2-F1-model_v4.pdb.gz      76
# ...                           ...                               ...     ...
# 119813  AF-Q382D1-F1-model_v4.pdb      AF-Q8GF06-F1-model_v4.pdb.gz      87
# 119870  AF-Q57VS1-F1-model_v4.pdb  AF-A0A133CZA4-F1-model_v4.cif.gz      32
# 120018  AF-C9ZZI6-F1-model_v4.pdb  AF-A0A1M2WJM2-F1-model_v4.pdb.gz      41
# 120036  AF-Q382M0-F1-model_v4.pdb  AF-A0A5P3FTA1-F1-model_v4.pdb.gz      46
# 120405  AF-Q38B31-F1-model_v4.pdb  AF-A0A132Z5J1-F1-model_v4.pdb.gz      47
#
#         fident        evalue  qstart  ...  tstart  tend  tlen  \
# 341      0.068  5.196000e-02      62  ...       0   108   110
# 457      0.198  6.546000e-02       0  ...       0   106   107
# 745      0.197  1.597000e-21     111  ...       0   352   436
# 784      0.146  2.133000e-13     111  ...       0   436   441
# 1261     0.131  3.967000e-04      43  ...       0   596   597
# ...        ...           ...     ...  ...     ...   ...   ...
# 119813   0.088  1.095000e-03     185  ...       1   118   134
# 119870   0.208  4.009000e-01     543  ...       5    49    62
# 120018   0.135  1.809000e-01       3  ...       0    56    60
# 120036   0.086  4.801000e-02      21  ...      35   133   136
# 120405   0.101  8.625000e-03       2  ...       8   178   205
#
#                                              aligmentinfo     proteome    spp  \
# 341                                 8M3D10M7I9M1D34M1I44M  UP000000559  CANAL
# 457                           18M2I14M2D18M4I33M2I13M1I9M  UP000000559  CANAL
# 745     10M11I35M1I41M5D5M4I35M2I43M2I12M3I19M1I14M17I...  UP000000559  CANAL
# 784     36M1I98M4I38M10I9M9I9M22I18M4I35M6D3M4D38M9I7M...  UP000000559  CANAL
# 1261    45M31I25M2I29M1D63M1D20M3I39M5I20M3I41M17I12M2...  UP000000559  CANAL
# ...                                                   ...          ...    ...
# 119813                 18M5D24M2I4M1D4M3I1M1D31M16D5M1I8M  UP000325664  ENTFC
# 119870                                       6M3D15M3I21M  UP000325664  ENTFC
# 120018                                  6M1I13M2D25M1I11M  UP000325664  ENTFC
# 120036                                 6M3I10M1I26M12I57M  UP000325664  ENTFC
# 120405  6M1I23M12I15M15D2M3D33M10D1M4I16M6D10M2D8M4D6M...  UP000325664  ENTFC
#
#        query_uniprot_accession target_uniprot_accession COV_query COV_target
# 341                     C9ZK61                   Q5ADW0      0.64       0.98
# 457                     D0AA93                   Q5A512      0.99       0.99
# 745                     Q582F3               A0A1D8PQM1      0.66       0.81
# 784                     Q388H5                   Q5A7R0      0.81       0.99
# 1261                    Q57XT6                   Q5APU2      0.79       1.00
# ...                        ...                      ...       ...        ...
# 119813                  Q382D1                   Q8GF06      0.23       0.87
# 119870                  Q57VS1               A0A133CZA4      0.05       0.71
# 120018                  C9ZZI6               A0A1M2WJM2      0.42       0.93
# 120036                  Q382M0               A0A5P3FTA1      0.50       0.72
# 120405                  Q38B31               A0A132Z5J1      0.72       0.83
#
# [1193 rows x 22 columns]

# %%
df_merged[df_merged['Ortholog_Group'] == 'OG6_100266'].sort_values('fident')
# Out:
#        Ortholog_Group          Gene ID     uniprot  pLDDT_mean  \
# 135284     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 134129     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 99845      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 132753     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 79133      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 80694      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 85434      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 140146     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 110974     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 87766      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 8662       OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 99379      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 76507      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 86439      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 102352     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 88973      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 101530     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 70617      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 73629      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 96892      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 25789      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 137401     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 111423     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 5231       OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 122204     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 124133     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 104326     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 14434      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 108833     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 129704     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 32549      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 2849       OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 94333      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 60724      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 40900      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 1497       OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 57137      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 120613     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 120614     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 84987      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 128022     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 55432      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 20558      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 22852      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 43118      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 12558      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 117985     OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 50097      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
# 67898      OG6_100266  LpyrH10_02_7100  A0A0N0DZL4        92.0
#
#                                 query                            target  \
# 135284  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0H3GU14-F1-model_v4.pdb.gz
# 134129  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P9WH65-F1-model_v4.pdb.gz
# 99845   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-K0ENE8-F1-model_v4.pdb.gz
# 132753  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q9X7A0-F1-model_v4.pdb.gz
# 79133   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-X8FIH5-F1-model_v4.pdb.gz
# 80694   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P56018-F1-model_v4.pdb.gz
# 85434   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q9PM82-F1-model_v4.pdb.gz
# 140146  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0M1PG85-F1-model_v4.pdb.gz
# 110974  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P66360-F1-model_v4.pdb.gz
# 87766   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q5F5V0-F1-model_v4.pdb.gz
# 8662    AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q2FW31-F1-model_v4.pdb.gz
# 99379   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q9HWF8-F1-model_v4.pdb.gz
# 76507   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P0A7R9-F1-model_v4.pdb.gz
# 86439   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q32B54-F1-model_v4.pdb.gz
# 102352  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-O54296-F1-model_v4.pdb.gz
# 88973   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P44379-F1-model_v4.cif.gz
# 101530  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P54021-F1-model_v4.pdb.gz
# 70617   AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A3P7FLI6-F1-model_v4.pdb.gz
# 73629   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-G4VHS0-F1-model_v4.pdb.gz
# 96892   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q54EG3-F1-model_v4.pdb.gz
# 25789   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P06367-F1-model_v4.pdb.gz
# 137401  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0N4UMW8-F1-model_v4.pdb.gz
# 111423  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A5K1K925-F1-model_v4.pdb.gz
# 5231    AF-A0A0N0DZL4-F1-model_v4.pdb      AF-C0HKA0-F1-model_v4.pdb.gz
# 122204  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A1S0QIB0-F1-model_v4.pdb.gz
# 124133  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-C0NVE4-F1-model_v4.pdb.gz
# 104326  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A077YZK6-F1-model_v4.pdb.gz
# 14434   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-C1GSD8-F1-model_v4.pdb.gz
# 108833  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A044UWM6-F1-model_v4.pdb.gz
# 129704  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0K0DVK8-F1-model_v4.cif.gz
# 32549   AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0R0FZ23-F1-model_v4.pdb.gz
# 2849    AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A0D2GW10-F1-model_v4.pdb.gz
# 94333   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P19951-F1-model_v4.pdb.gz
# 60724   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P48150-F1-model_v4.pdb.gz
# 40900   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q6H7T1-F1-model_v4.pdb.gz
# 1497    AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A1D8PDT3-F1-model_v4.pdb.gz
# 57137   AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A1C1CRT8-F1-model_v4.pdb.gz
# 120613  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P0CT56-F1-model_v4.pdb.gz
# 120614  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P0CT57-F1-model_v4.pdb.gz
# 84987   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q6PBW3-F1-model_v4.pdb.gz
# 128022  AF-A0A0N0DZL4-F1-model_v4.pdb  AF-A0A175VV65-F1-model_v4.pdb.gz
# 55432   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-U7PNV7-F1-model_v4.cif.gz
# 20558   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P62264-F1-model_v4.pdb.gz
# 22852   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P13471-F1-model_v4.pdb.gz
# 43118   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-P62263-F1-model_v4.pdb.gz
# 12558   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q9SIH0-F1-model_v4.pdb.gz
# 117985  AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q4FKG9-F1-model_v4.pdb.gz
# 50097   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-Q4D6I5-F1-model_v4.pdb.gz
# 67898   AF-A0A0N0DZL4-F1-model_v4.pdb      AF-A4I650-F1-model_v4.pdb.gz
#
#         alnlen  fident        evalue  qstart  ...  qlen  tstart  tend  tlen  \
# 135284     124   0.192  2.458000e-04      21  ...   144      23   115   117
# 134129     419   0.272  4.180000e-14       0  ...   144       4   138   139
# 99845      391   0.275  5.051000e-13       0  ...   144       0   136   137
# 132753     420   0.292  3.137000e-14       0  ...   144       3   137   138
# 79133      227   0.295  4.550000e-07      35  ...   144       1    96    98
# 80694      395   0.297  3.319000e-13       0  ...   144       0   129   131
# 85434      402   0.304  2.312000e-13       0  ...   144       0   128   130
# 140146     397   0.307  6.543000e-13       0  ...   144       0   127   129
# 110974     422   0.307  1.769000e-13       0  ...   144       0   125   127
# 87766      412   0.308  1.280000e-13       0  ...   144       0   130   131
# 8662       416   0.321  1.511000e-13       0  ...   144       0   127   129
# 99379      427   0.349  4.100000e-14       0  ...   144       0   128   129
# 76507      432   0.354  2.246000e-14       0  ...   144       0   127   129
# 86439      432   0.354  1.971000e-14       0  ...   144       0   127   129
# 102352     438   0.361  1.377000e-14       0  ...   144       0   127   129
# 88973      448   0.368  5.643000e-15       0  ...   144       0   127   129
# 101530     720   0.523  5.875000e-20      13  ...   144       1   126   129
# 70617      980   0.610  1.780000e-26       0  ...   144       7   178   179
# 73629     1018   0.691  3.278000e-27       0  ...   144       6   151   152
# 96892     1021   0.715  2.426000e-27       0  ...   144       8   151   152
# 25789      994   0.722  9.636000e-27       7  ...   144       0   136   137
# 137401    1046   0.724  2.936000e-28       0  ...   144       6   150   151
# 111423    1029   0.726  3.155000e-28       0  ...   144       1   150   151
# 5231      1062   0.729  3.693000e-28       0  ...   144       7   150   151
# 122204    1076   0.729  1.360000e-28       0  ...   144       7   150   151
# 124133    1081   0.736  1.582000e-28       0  ...   144       7   150   151
# 104326    1055   0.741  2.444000e-28       1  ...   144       7   149   150
# 14434     1073   0.741  2.575000e-28       1  ...   144       8   150   151
# 108833    1071   0.741  1.764000e-28       1  ...   144       8   150   151
# 129704    1083   0.743  1.441000e-28       0  ...   144       7   150   151
# 32549     1094   0.755  1.346000e-28       1  ...   144       7   149   150
# 2849      1065   0.755  3.822000e-28       1  ...   144       8   150   151
# 94333     1082   0.756  1.654000e-28       0  ...   144       6   149   150
# 60724     1094   0.756  6.664000e-29       0  ...   144       8   151   152
# 40900     1096   0.756  1.155000e-28       0  ...   144       6   149   150
# 1497       957   0.759  2.398000e-25      15  ...   144       3   131   132
# 57137     1072   0.762  2.342000e-28       1  ...   144       8   150   194
# 120613    1046   0.769  9.323000e-28       5  ...   144       0   138   139
# 120614    1046   0.769  9.323000e-28       5  ...   144       0   138   139
# 84987     1083   0.769  1.764000e-28       1  ...   144       8   150   151
# 128022    1096   0.770  6.016000e-29       0  ...   144       6   149   150
# 55432     1090   0.770  8.805000e-29       0  ...   144       6   149   150
# 20558     1064   0.776  5.923000e-28       1  ...   144       8   150   151
# 22852     1090   0.776  1.288000e-28       1  ...   144       8   150   151
# 43118     1063   0.776  6.967000e-28       1  ...   144       8   150   151
# 12558     1106   0.777  5.101000e-29       0  ...   144       6   149   150
# 117985    1143   0.902  6.577000e-31       0  ...   144       0   143   144
# 50097     1135   0.902  4.357000e-30       0  ...   144       0   143   144
# 67898     1218   0.958  5.539000e-32       0  ...   144       0   143   144
#
#            proteome     spp query_uniprot_accession target_uniprot_accession  \
# 135284  UP000007841   KLEPH              A0A0N0DZL4               A0A0H3GU14
# 134129  UP000001584   MYCTU              A0A0N0DZL4                   P9WH65
# 99845   UP000006304  9NOCA1              A0A0N0DZL4                   K0ENE8
# 132753  UP000000806   MYCLE              A0A0N0DZL4                   Q9X7A0
# 79133   UP000020681   MYCUL              A0A0N0DZL4                   X8FIH5
# 80694   UP000000429   HELPY              A0A0N0DZL4                   P56018
# 85434   UP000000799   CAMJE              A0A0N0DZL4                   Q9PM82
# 140146  UP000325664   ENTFC              A0A0N0DZL4               A0A0M1PG85
# 110974  UP000000586   STRR6              A0A0N0DZL4                   P66360
# 87766   UP000000535   NEIG1              A0A0N0DZL4                   Q5F5V0
# 8662    UP000008816   STAA8              A0A0N0DZL4                   Q2FW31
# 99379   UP000002438   PSEAE              A0A0N0DZL4                   Q9HWF8
# 76507   UP000000625   ECOLI              A0A0N0DZL4                   P0A7R9
# 86439   UP000002716   SHIDS              A0A0N0DZL4                   Q32B54
# 102352  UP000001014   SALTY              A0A0N0DZL4                   O54296
# 88973   UP000000579   HAEIN              A0A0N0DZL4                   P44379
# 101530  UP000000805   METJA              A0A0N0DZL4                   P54021
# 70617   UP000270924   WUCBA              A0A0N0DZL4               A0A3P7FLI6
# 73629   UP000008854   SCHMA              A0A0N0DZL4                   G4VHS0
# 96892   UP000002195   DICDI              A0A0N0DZL4                   Q54EG3
# 25789   UP000002311   YEAST              A0A0N0DZL4                   P06367
# 137401  UP000274756   DRAME              A0A0N0DZL4               A0A0N4UMW8
# 111423  UP000001450   PLAF7              A0A0N0DZL4               A0A5K1K925
# 5231    UP000000803   DROME              A0A0N0DZL4                   C0HKA0
# 122204  UP000006672   BRUMA              A0A0N0DZL4               A0A1S0QIB0
# 124133  UP000001631   AJECG              A0A0N0DZL4                   C0NVE4
# 104326  UP000030665   TRITR              A0A0N0DZL4               A0A077YZK6
# 14434   UP000002059   PARBA              A0A0N0DZL4                   C1GSD8
# 108833  UP000024404   ONCVO              A0A0N0DZL4               A0A044UWM6
# 129704  UP000035681   STRER              A0A0N0DZL4               A0A0K0DVK8
# 32549   UP000008827   SOYBN              A0A0N0DZL4               A0A0R0FZ23
# 2849    UP000053029  9EURO2              A0A0N0DZL4               A0A0D2GW10
# 94333   UP000007305   MAIZE              A0A0N0DZL4                   P19951
# 60724   UP000001940   CAEEL              A0A0N0DZL4                   P48150
# 40900   UP000059680   ORYSJ              A0A0N0DZL4                   Q6H7T1
# 1497    UP000000559   CANAL              A0A0N0DZL4               A0A1D8PDT3
# 57137   UP000094526  9EURO1              A0A0N0DZL4               A0A1C1CRT8
# 120613  UP000002485   SCHPO              A0A0N0DZL4                   P0CT56
# 120614  UP000002485   SCHPO              A0A0N0DZL4                   P0CT57
# 84987   UP000000437   DANRE              A0A0N0DZL4                   Q6PBW3
# 128022  UP000078237  9PEZI1              A0A0N0DZL4               A0A175VV65
# 55432   UP000018087   SPOS1              A0A0N0DZL4                   U7PNV7
# 20558   UP000000589   MOUSE              A0A0N0DZL4                   P62264
# 22852   UP000002494     RAT              A0A0N0DZL4                   P13471
# 43118   UP000005640   HUMAN              A0A0N0DZL4                   P62263
# 12558   UP000006548   ARATH              A0A0N0DZL4                   Q9SIH0
# 117985  UP000008524   TRYB2              A0A0N0DZL4                   Q4FKG9
# 50097   UP000002296   TRYCC              A0A0N0DZL4                   Q4D6I5
# 67898   UP000008153   LEIIN              A0A0N0DZL4                   A4I650
#
#        COV_query  COV_target
# 135284      0.67        0.79
# 134129      0.99        0.96
# 99845       0.99        0.99
# 132753      0.99        0.97
# 79133       0.72        0.97
# 80694       0.97        0.98
# 85434       0.97        0.98
# 140146      0.97        0.98
# 110974      0.97        0.98
# 87766       0.99        0.99
# 8662        0.97        0.98
# 99379       0.99        0.99
# 76507       0.97        0.98
# 86439       0.97        0.98
# 102352      0.97        0.98
# 88973       0.97        0.98
# 101530      0.87        0.97
# 70617       0.99        0.96
# 73629       0.99        0.95
# 96892       0.99        0.94
# 25789       0.94        0.99
# 137401      0.99        0.95
# 111423      0.99        0.99
# 5231        0.99        0.95
# 122204      0.99        0.95
# 124133      0.99        0.95
# 104326      0.99        0.95
# 14434       0.99        0.94
# 108833      0.99        0.94
# 129704      0.99        0.95
# 32549       0.99        0.95
# 2849        0.99        0.94
# 94333       0.99        0.95
# 60724       0.99        0.94
# 40900       0.99        0.95
# 1497        0.89        0.97
# 57137       0.99        0.73
# 120613      0.96        0.99
# 120614      0.96        0.99
# 84987       0.99        0.94
# 128022      0.99        0.95
# 55432       0.99        0.95
# 20558       0.99        0.94
# 22852       0.99        0.94
# 43118       0.99        0.94
# 12558       0.99        0.95
# 117985      0.99        0.99
# 50097       0.99        0.99
# 67898       0.99        0.99
#
# [49 rows x 21 columns]
