# %%
import pandas as pd

# %%
def get_only_uniprot_accession(df, colname):
    
    colname_out = colname + '_uniprot_accession'
    
    df[colname_out] = df[colname].str.split('-', expand=True)[1]
    
    return df


def calc_coverage(df, which_one ,start, end, lenght):
    
    col_name = 'COV_' + which_one
    
    df[col_name] = (df.loc[: , end] - df.loc[: , start]) / df.loc[: , lenght]
    
    df[col_name] = df[col_name].round(2)
    
    return df

# %% [markdown]
# ## Importing df

# %%
df = pd.read_csv('../../../../results/foldseek_search_TSV/cluster_representer_vs_SwissProt.tsv', 
            sep='\t', 
            names = ['query','target','alnlen','fident', 'evalue', 'qstart','qend', 'qlen','tstart','tend','tlen','aligmentinfo'])

# %% [markdown]
# ## modifing columns

# %%
df = (df
 .pipe(get_only_uniprot_accession, 'query')
 .pipe(get_only_uniprot_accession, 'target')
 .pipe(calc_coverage, 'query', 'qstart', 'qend','qlen')
 .pipe(calc_coverage, 'target', 'tstart', 'tend','tlen'))

print(df.shape)

df = df.drop_duplicates(['query_uniprot_accession', 'target_uniprot_accession'])

print(df.shape)
# Out:
# (1384377, 16)
# (1384377, 16)

# %%
df
# Out:
#                                  query                        target  alnlen  \
# 0        AF-A0A0N0VF31-F1-model_v4.pdb  AF-A6ZQ47-F1-model_v2.pdb.gz      67
# 1        AF-A0A0S4J2B2-F1-model_v4.pdb  AF-Q148L1-F1-model_v2.pdb.gz     882
# 2        AF-A0A0S4J2B2-F1-model_v4.pdb  AF-Q5FWM8-F1-model_v2.pdb.gz     310
# 3        AF-A0A0S4J2B2-F1-model_v4.pdb  AF-Q28EW0-F1-model_v2.pdb.gz     285
# 4        AF-A0A0S4J2B2-F1-model_v4.pdb  AF-A6ZZS6-F1-model_v2.pdb.gz     257
# ...                                ...                           ...     ...
# 1384372  AF-A0A0S4JB70-F1-model_v4.pdb  AF-P23393-F1-model_v2.pdb.gz     260
# 1384373  AF-A0A0S4JB70-F1-model_v4.pdb  AF-Q17QR8-F1-model_v2.pdb.gz     234
# 1384374  AF-A0A0S4JB70-F1-model_v4.pdb  AF-Q00840-F1-model_v2.pdb.gz     125
# 1384375  AF-A0A0S4JB70-F1-model_v4.pdb  AF-O70075-F1-model_v2.pdb.gz     108
# 1384376  AF-A0A0S4JB70-F1-model_v4.pdb  AF-Q45620-F1-model_v2.pdb.gz     107
#
#          fident        evalue  qstart  qend  qlen  tstart  tend  tlen  \
# 0         0.100  2.390000e-04       0   896   898     488  1277  1447
# 1         0.237  1.566000e-24      20   459   460      35   537   548
# 2         0.139  2.959000e-11       0   459   460       0   424   435
# 3         0.121  6.074000e-10       0   434   460       6   450   541
# 4         0.106  3.201000e-09       2   459   460      10   481   523
# ...         ...           ...     ...   ...   ...     ...   ...   ...
# 1384372   0.194  1.318000e-07       3   253   333      10   251   256
# 1384373   0.129  5.451000e-08      14   302   333      43   344   349
# 1384374   0.132  3.363000e-04      66   263   333      43   287   288
# 1384375   0.110  7.722000e-04       1   257   333      17   303   321
# 1384376   0.131  9.505000e-04       2   255   333       8   321   377
#
#                                               aligmentinfo  \
# 0        27M1I32M2D5M20I25M1D22M12D6M6D9M72I21M4D4M43I3...
# 1        36M5I3M3I5M1D10M1I8M6I11M2I4M1I9M9D4M58D6M12D6...
# 2        29M3D10M1D12M2I7M13I19M6I6M3I10M2I1M8I10M3D12M...
# 3        15M5D10M3D3M2I3M1I23M8I1M3I26M3I14M10D9M26D11M...
# 4        15M1I9M1I4M3I6M8D12M11I8M1I8M7D8M5D8M1D7M7D7M1...
# ...                                                    ...
# 1384372  22M13D27M3I2M3I10M8I13M5I6M1D12M6I7M1I15M1D48M...
# 1384373  9M11D22M3I29M5I9M5D11M6D14M3I10M1I46M5D7M1D13M...
# 1384374  8M10D20M2D8M2D10M3D13M16D26M1I8M3I10M2D13M9D3M...
# 1384375  8M4I16M11D41M3I6M2I21M3D20M5I6M3D9M1D6M2D2M1I2...
# 1384376  11M3I9M4D4M3D44M1D7M1D7M3I6M2D15M4I13M2I13M1D8...
#
#         query_uniprot_accession target_uniprot_accession  COV_query  \
# 0                    A0A0N0VF31                   A6ZQ47       1.00
# 1                    A0A0S4J2B2                   Q148L1       0.95
# 2                    A0A0S4J2B2                   Q5FWM8       1.00
# 3                    A0A0S4J2B2                   Q28EW0       0.94
# 4                    A0A0S4J2B2                   A6ZZS6       0.99
# ...                         ...                      ...        ...
# 1384372              A0A0S4JB70                   P23393       0.75
# 1384373              A0A0S4JB70                   Q17QR8       0.86
# 1384374              A0A0S4JB70                   Q00840       0.59
# 1384375              A0A0S4JB70                   O70075       0.77
# 1384376              A0A0S4JB70                   Q45620       0.76
#
#          COV_target
# 0              0.55
# 1              0.92
# 2              0.97
# 3              0.82
# 4              0.90
# ...             ...
# 1384372        0.94
# 1384373        0.86
# 1384374        0.85
# 1384375        0.89
# 1384376        0.83
#
# [1384377 rows x 16 columns]

# %%
df[
    (df['COV_query'] > .8) &
    (df['COV_target'] > .8) &
    (df['evalue'] < 1e-5)].sort_values('evalue')

# %%
df[df['query_uniprot_accession'] == 'A0A7G2CMN2']
# Out:
# Empty DataFrame
# Columns: [query, target, alnlen, fident, evalue, qstart, qend, qlen, tstart, tend, tlen, aligmentinfo, query_uniprot_accession, target_uniprot_accession, COV_query, COV_target]
# Index: []
