# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
import os

directory = "../tmp/FATCAT_aligments/"
lines_list = []

for filename in os.listdir(directory):
    if filename.endswith(".aln"):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            with open(filepath, 'r') as file:
                lines = [file.readline().strip() for _ in range(3)]
                #lines_list.extend(lines)
                lines = ' '.join(lines).split()
                lines_list.append(lines)

#print(lines_list)

# %%
print(lines_list[:10])
# Out:
# [['Align', 'A0A0S4JM71.pdb', '153', 'with', 'Q0DLD3.pdb', '106', 'Twists', '0', 'ini-len', '96', 'ini-rmsd', '1.67', 'opt-equ', '100', 'opt-rmsd', '1.76', 'chain-rmsd', '1.67', 'Score', '215.04', 'align-len', '144', 'gaps', '44', '(30.56%)', 'P-value', '9.31e-11', 'Afp-num', '5272', 'Identity', '19.44%', 'Similarity', '31.25%'], ['Align', 'A0A061J7H0.pdb', '644', 'with', 'A0A0N7KJF7.pdb', '76', 'Twists', '2', 'ini-len', '48', 'ini-rmsd', '5.14', 'opt-equ', '62', 'opt-rmsd', '2.76', 'chain-rmsd', '12.09', 'Score', '74.64', 'align-len', '105', 'gaps', '43', '(40.95%)', 'P-value', '9.13e-01', 'Afp-num', '14720', 'Identity', '8.57%', 'Similarity', '17.14%'], ['Align', 'A0A7J6XS94.pdb', '210', 'with', 'A0A1C1CY31.pdb', '84', 'Twists', '1', 'ini-len', '72', 'ini-rmsd', '2.56', 'opt-equ', '74', 'opt-rmsd', '2.70', 'chain-rmsd', '20.33', 'Score', '161.43', 'align-len', '83', 'gaps', '9', '(10.84%)', 'P-value', '1.87e-03', 'Afp-num', '8267', 'Identity', '7.23%', 'Similarity', '19.28%'], ['Align', 'Q4DI52.pdb', '463', 'with', 'X8F197.pdb', '236', 'Twists', '1', 'ini-len', '128', 'ini-rmsd', '4.63', 'opt-equ', '178', 'opt-rmsd', '3.06', 'chain-rmsd', '8.51', 'Score', '247.90', 'align-len', '385', 'gaps', '207', '(53.77%)', 'P-value', '7.85e-04', 'Afp-num', '34968', 'Identity', '4.42%', 'Similarity', '11.43%'], ['Align', 'A0A7J6XUI9.pdb', '222', 'with', 'P9WLT9.pdb', '222', 'Twists', '5', 'ini-len', '152', 'ini-rmsd', '4.24', 'opt-equ', '173', 'opt-rmsd', '3.26', 'chain-rmsd', '31.15', 'Score', '254.00', 'align-len', '218', 'gaps', '45', '(20.64%)', 'P-value', '3.87e-03', 'Afp-num', '19484', 'Identity', '3.67%', 'Similarity', '12.39%'], ['Align', 'Tb927105770.pdb', '780', 'with', 'P54811.pdb', '809', 'Twists', '2', 'ini-len', '752', 'ini-rmsd', '2.27', 'opt-equ', '770', 'opt-rmsd', '2.39', 'chain-rmsd', '11.98', 'Score', '2148.57', 'align-len', '781', 'gaps', '11', '(1.41%)', 'P-value', '0.00e+00', 'Afp-num', '234039', 'Identity', '68.50%', 'Similarity', '82.33%'], ['Align', 'A0A0N0VEW5.pdb', '346', 'with', 'A0A1C1CJL4.pdb', '281', 'Twists', '4', 'ini-len', '184', 'ini-rmsd', '5.67', 'opt-equ', '183', 'opt-rmsd', '3.40', 'chain-rmsd', '21.28', 'Score', '276.34', 'align-len', '298', 'gaps', '115', '(38.59%)', 'P-value', '8.67e-03', 'Afp-num', '36737', 'Identity', '6.04%', 'Similarity', '16.11%'], ['Align', 'Q580M3.pdb', '645', 'with', 'I1KGC3.pdb', '640', 'Twists', '0', 'ini-len', '560', 'ini-rmsd', '3.88', 'opt-equ', '606', 'opt-rmsd', '3.08', 'chain-rmsd', '3.88', 'Score', '1563.04', 'align-len', '656', 'gaps', '50', '(7.62%)', 'P-value', '0.00e+00', 'Afp-num', '154414', 'Identity', '34.60%', 'Similarity', '53.51%'], ['Align', 'Tb92784690.pdb', '124', 'with', 'A0A1D6EU85.pdb', '118', 'Twists', '2', 'ini-len', '64', 'ini-rmsd', '3.60', 'opt-equ', '67', 'opt-rmsd', '3.29', 'chain-rmsd', '16.96', 'Score', '66.59', 'align-len', '99', 'gaps', '32', '(32.32%)', 'P-value', '4.01e-01', 'Afp-num', '4986', 'Identity', '10.10%', 'Similarity', '19.19%'], ['Align', 'A0A640KC22.pdb', '1084', 'with', 'A0A1C1C774.pdb', '432', 'Twists', '2', 'ini-len', '224', 'ini-rmsd', '10.68', 'opt-equ', '284', 'opt-rmsd', '3.20', 'chain-rmsd', '21.48', 'Score', '420.23', 'align-len', '484', 'gaps', '200', '(41.32%)', 'P-value', '3.51e-03', 'Afp-num', '159224', 'Identity', '14.46%', 'Similarity', '23.35%']]

# %%
pd.DataFrame(lines_list)
# Out:
#           0                1     2     3               4     5       6  7   \
# 0      Align   A0A0S4JM71.pdb   153  with      Q0DLD3.pdb   106  Twists  0
# 1      Align   A0A061J7H0.pdb   644  with  A0A0N7KJF7.pdb    76  Twists  2
# 2      Align   A0A7J6XS94.pdb   210  with  A0A1C1CY31.pdb    84  Twists  1
# 3      Align       Q4DI52.pdb   463  with      X8F197.pdb   236  Twists  1
# 4      Align   A0A7J6XUI9.pdb   222  with      P9WLT9.pdb   222  Twists  5
# ...      ...              ...   ...   ...             ...   ...     ... ..
# 40347  Align   A0A2V2W775.pdb   831  with      Q05895.pdb   956  Twists  5
# 40348  Align       D6XIY7.pdb   466  with  A0A5K4EXN5.pdb   444  Twists  3
# 40349  Align  Tb927912500.pdb   524  with  A0A133CJ97.pdb   131  Twists  4
# 40350  Align       Q385C5.pdb   441  with      O14097.pdb   331  Twists  5
# 40351  Align       A4HY90.pdb  2280  with      Q54NP8.pdb  1922  Twists  2
#
#             8     9         10     11       12    13        14     15  \
# 0      ini-len    96  ini-rmsd   1.67  opt-equ   100  opt-rmsd   1.76
# 1      ini-len    48  ini-rmsd   5.14  opt-equ    62  opt-rmsd   2.76
# 2      ini-len    72  ini-rmsd   2.56  opt-equ    74  opt-rmsd   2.70
# 3      ini-len   128  ini-rmsd   4.63  opt-equ   178  opt-rmsd   3.06
# 4      ini-len   152  ini-rmsd   4.24  opt-equ   173  opt-rmsd   3.26
# ...        ...   ...       ...    ...      ...   ...       ...    ...
# 40347  ini-len   208  ini-rmsd   5.62  opt-equ   244  opt-rmsd   3.13
# 40348  ini-len   352  ini-rmsd   3.52  opt-equ   374  opt-rmsd   2.15
# 40349  ini-len    96  ini-rmsd   3.61  opt-equ   111  opt-rmsd   2.82
# 40350  ini-len   248  ini-rmsd  13.91  opt-equ   192  opt-rmsd   4.66
# 40351  ini-len  1696  ini-rmsd  66.58  opt-equ  1014  opt-rmsd  19.29
#
#                16     17     18       19         20    21    22    23  \
# 0      chain-rmsd   1.67  Score   215.04  align-len   144  gaps    44
# 1      chain-rmsd  12.09  Score    74.64  align-len   105  gaps    43
# 2      chain-rmsd  20.33  Score   161.43  align-len    83  gaps     9
# 3      chain-rmsd   8.51  Score   247.90  align-len   385  gaps   207
# 4      chain-rmsd  31.15  Score   254.00  align-len   218  gaps    45
# ...           ...    ...    ...      ...        ...   ...   ...   ...
# 40347  chain-rmsd  33.26  Score   255.59  align-len   441  gaps   197
# 40348  chain-rmsd   8.34  Score   801.73  align-len   473  gaps    99
# 40349  chain-rmsd  19.85  Score   175.32  align-len   125  gaps    14
# 40350  chain-rmsd  49.27  Score   312.17  align-len   340  gaps   148
# 40351  chain-rmsd  74.60  Score  3860.05  align-len  2606  gaps  1592
#
#              24       25        26       27       28        29      30  \
# 0      (30.56%)  P-value  9.31e-11  Afp-num     5272  Identity  19.44%
# 1      (40.95%)  P-value  9.13e-01  Afp-num    14720  Identity   8.57%
# 2      (10.84%)  P-value  1.87e-03  Afp-num     8267  Identity   7.23%
# 3      (53.77%)  P-value  7.85e-04  Afp-num    34968  Identity   4.42%
# 4      (20.64%)  P-value  3.87e-03  Afp-num    19484  Identity   3.67%
# ...         ...      ...       ...      ...      ...       ...     ...
# 40347  (44.67%)  P-value  4.84e-01  Afp-num   239053  Identity   3.63%
# 40348  (20.93%)  P-value  1.49e-12  Afp-num    67487  Identity  27.91%
# 40349  (11.20%)  P-value  2.21e-01  Afp-num    22240  Identity   6.40%
# 40350  (43.53%)  P-value  4.92e-02  Afp-num    68352  Identity   8.24%
# 40351  (61.09%)  P-value  6.17e-09  Afp-num  2324317  Identity   6.45%
#
#                31      32
# 0      Similarity  31.25%
# 1      Similarity  17.14%
# 2      Similarity  19.28%
# 3      Similarity  11.43%
# 4      Similarity  12.39%
# ...           ...     ...
# 40347  Similarity   9.30%
# 40348  Similarity  43.76%
# 40349  Similarity  15.20%
# 40350  Similarity  20.59%
# 40351  Similarity  14.66%
#
# [40352 rows x 33 columns]
